# %% [markdown]
# ## Load and imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('half_dataset.zip', header=[0, 1])

# %% [markdown]
# ## Task 2

# %%
df.columns
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',   'Unnamed: 0_level_1'),
#             (   'timestamp_second',   'Unnamed: 0_level_1'),
#             (        'bid_price_0',              'nunique'),
#             (        'bid_price_0',                 'mean'),
#             (        'bid_price_0',               'median'),
#             (        'bid_price_0',                  'std'),
#             (        'bid_price_0',                  'min'),
#             (        'bid_price_0',                  'max'),
#             (        'bid_price_0',                'first'),
#             (        'bid_price_0',                 'last'),
#             ...
#             ('sell_trade_quantity',                  'sum'),
#             ('sell_trade_quantity',                 'mean'),
#             ('sell_trade_quantity',               'median'),
#             ('sell_trade_quantity',                  'std'),
#             ('sell_trade_quantity',                  'min'),
# ...

# %%
plt.plot(df['bid_price_0']['mean'])
plt.plot(df['ask_price_0']['mean'])

# %% [markdown]
# ## Task 3

# %% [markdown]
# Лучше использовать текущую целевую переменную, так как она собственно и равна тому что мы хотим найти (S[t + 60] - S[t]), в то время как цена по сути нам известна и без модели (просто дана во входных данных).
